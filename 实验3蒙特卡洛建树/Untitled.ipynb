# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
#import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
path1_1=r'C:\Users\pro\Desktop\实验三蒙特卡洛树\05_9提高本方法的效果_树长为指标'
data1=pd.read_csv(os.path.join(path1_1,"01_Yang2015.nex.csv"))
data2=pd.read_csv(os.path.join(path1_1,"02_Aria2015.nex.csv"))
data3=pd.read_csv(os.path.join(path1_1,"03_Liu2011.nex.csv"))
data4=pd.read_csv(os.path.join(path1_1,"04_Longrich2010.nex.csv"))
data5=pd.read_csv(os.path.join(path1_1,"05_Dikow2009.nex.csv"))
data1
# Out:
#    Unnamed: 0        V1
# 0           1  0.465116
# 1           2  0.441860
# 2           3  0.488372
# 3           4  0.441860
# 4           5  0.558140
# 5           6  0.441860
# 6           7  0.465116
# 7           8  0.465116

# %%
del data1['Unnamed: 0']
del data2['Unnamed: 0']
del data3['Unnamed: 0']
del data4['Unnamed: 0']
del data5['Unnamed: 0']
data1=data1.T
data2=data2.T
data3=data3.T
data4=data4.T
data5=data5.T
data1
# Out:
#            0        1         2        3        4        5         6         7
# V1  0.465116  0.44186  0.488372  0.44186  0.55814  0.44186  0.465116  0.465116

# %%
data2
# Out:
#            0         1         2         3         4         5         6  \
# V1  0.546875  0.546875  0.453125  0.390625  0.609375  0.390625  0.546875
# V2  0.390625  0.390625  0.328125  0.296875  0.484375  0.328125  0.390625
#
#            7
# V1  0.453125
# V2  0.359375

# %%
data3
# Out:
#        0     1     2     3     4     5     6     7
# V1  0.16  0.16  0.12  0.16  0.16  0.16  0.16  0.12

# %%
data4
# Out:
#            0         1         2         3         4         5         6  \
# V1  0.823529  0.823529  0.352941  0.470588  0.470588  0.470588  0.529412
#
#            7
# V1  0.411765

# %%
data5
# Out:
#            0         1         2         3         4         5         6  \
# V1  0.329412  0.329412  0.388235  0.388235  0.352941  0.388235  0.364706
#
#            7
# V1  0.364706

# %%
data1.rename(columns={'0':'缺失本方法', '1':'插补后本方法', '2':'缺失NJ','3':'缺失UPGMA','4':'缺失ML','5':'缺失MP','6':'插补NJ','7':'插补UPGMA','8':'插补ML','9':'插补MP'}, inplace = True)
data2.rename(columns={'0':'缺失本方法', '1':'插补后本方法', '2':'缺失NJ','3':'缺失UPGMA','4':'缺失ML','5':'缺失MP','6':'插补NJ','7':'插补UPGMA','8':'插补ML','9':'插补MP'}, inplace = True)
data3.rename(columns={'0':'缺失本方法', '1':'插补后本方法', '2':'缺失NJ','3':'缺失UPGMA','4':'缺失ML','5':'缺失MP','6':'插补NJ','7':'插补UPGMA','8':'插补ML','9':'插补MP'}, inplace = True)
data4.rename(columns={'0':'缺失本方法', '1':'插补后本方法', '2':'缺失NJ','3':'缺失UPGMA','4':'缺失ML','5':'缺失MP','6':'插补NJ','7':'插补UPGMA','8':'插补ML','9':'插补MP'}, inplace = True)
data5.rename(columns={'0':'缺失本方法', '1':'插补后本方法', '2':'缺失NJ','3':'缺失UPGMA','4':'缺失ML','5':'缺失MP','6':'插补NJ','7':'插补UPGMA','8':'插补ML','9':'插补MP'}, inplace = True)
data1
# Out:
#            0         1         2        3        4         5         6  \
# V1  0.581395  0.744186  0.488372  0.44186  0.55814  0.488372  0.488372
#
#           7         8         9
# V1  0.44186  0.523256  0.546512

# %%
# %matplotlib notebook
xticks=[0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75]
fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax1=plt.subplot(1,1,1)
data1.plot.bar(ax=ax1)
plt.show()

fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax1=plt.subplot(1,1,1)
data2.plot.bar(ax=ax1)
plt.show()

fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax1=plt.subplot(1,1,1)
data3.plot.bar(ax=ax1)
plt.show()

fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax1=plt.subplot(1,1,1)
data4.plot.bar(ax=ax1)
plt.show()

fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax1=plt.subplot(1,1,1)
data5.plot.bar(ax=ax1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">
# <img src="data:image/png;base64,..." width="699.999984827909">

# %%
path1_1=r'C:\Users\pro\Desktop\实验三蒙特卡洛树\05_5_加入bioNj'
data1=pd.read_csv(os.path.join(path1_1,"01_Yang2015.nexbasicMetric.csv")).T
data2=pd.read_csv(os.path.join(path1_1,"02_Aria2015.nexbasicMetric.csv")).T
data3=pd.read_csv(os.path.join(path1_1,"03_Liu2011.nexbasicMetric.csv")).T
data4=pd.read_csv(os.path.join(path1_1,"04_Longrich2010.nexbasicMetric.csv")).T
data5=pd.read_csv(os.path.join(path1_1,"05_Dikow2009.nexbasicMetric.csv")).T
data1
# Out:
#                      0           1           2          3           4  \
# Unnamed: 0    1.000000    2.000000    3.000000    4.00000    5.000000
# V1          329.000000  334.000000  340.000000  336.00000  317.000000
# V2          167.000000  167.000000  203.000000  213.00000  195.000000
# V3            0.534954    0.526946    0.517647    0.52381    0.555205
# V4            0.823936    0.818182    0.811277    0.81588    0.837745
#
#                      5           6           7
# Unnamed: 0    6.000000    7.000000    8.000000
# V1          340.000000  305.000000  347.000000
# V2          215.000000  207.000000  205.000000
# V3            0.517647    0.577049    0.507205
# V4            0.811277    0.851554    0.803222

# %%
data2
# Out:
#                      0           1           2           3           4  \
# Unnamed: 0    1.000000    2.000000    3.000000    4.000000    5.000000
# V1          176.000000  179.000000  180.000000  186.000000  172.000000
# V2          143.000000  143.000000  157.000000  161.000000  148.000000
# V3            0.437500    0.430168    0.427778    0.413978    0.447674
# V4            0.706231    0.697329    0.694362    0.676558    0.718101
#
#                      5           6           7
# Unnamed: 0    6.000000    7.000000    8.000000
# V1          181.000000  173.000000  183.000000
# V2          159.000000  150.000000  160.000000
# V3            0.425414    0.445087    0.420765
# V4            0.691395    0.715134    0.685460

# %%
data3
# Out:
#                      0           1           2           3           4  \
# Unnamed: 0    1.000000    2.000000    3.000000    4.000000    5.000000
# V1          129.000000  129.000000  131.000000  149.000000  129.000000
# V2           91.000000   91.000000   99.000000  113.000000   97.000000
# V3            0.472868    0.472868    0.465649    0.409396    0.472868
# V4            0.728000    0.728000    0.720000    0.648000    0.728000
#
#                      5           6           7
# Unnamed: 0    6.000000    7.000000    8.000000
# V1          133.000000  129.000000  138.000000
# V2           96.000000   97.000000  102.000000
# V3            0.458647    0.472868    0.442029
# V4            0.712000    0.728000    0.692000

# %%
data4
# Out:
#                      0           1           2           3           4  \
# Unnamed: 0    1.000000    2.000000    3.000000    4.000000    5.000000
# V1          166.000000  167.000000  180.000000  172.000000  170.000000
# V2          131.000000  131.000000  153.000000  147.000000  143.000000
# V3            0.704819    0.700599    0.650000    0.680233    0.688235
# V4            0.774194    0.769585    0.709677    0.746544    0.755760
#
#                      5           6           7
# Unnamed: 0    6.000000    7.000000    8.000000
# V1          173.000000  164.000000  174.000000
# V2          145.000000  141.000000  147.000000
# V3            0.676301    0.713415    0.672414
# V4            0.741935    0.783410    0.737327

# %%
data5
# Out:
#                       0            1            2            3            4  \
# Unnamed: 0     1.000000     2.000000     3.000000     4.000000     5.000000
# V1          1651.000000  1646.000000  1691.000000  1728.000000  1655.000000
# V2          1617.000000  1611.000000  1652.000000  1694.000000  1622.000000
# V3             0.224107     0.224787     0.218805     0.214120     0.223565
# V4             0.667877     0.669173     0.657506     0.647913     0.666840
#
#                       5            6            7
# Unnamed: 0     6.000000     7.000000     8.000000
# V1          1673.000000  1650.000000  1689.000000
# V2          1641.000000  1617.000000  1654.000000
# V3             0.221160     0.224242     0.219065
# V4             0.662173     0.668136     0.658024

# %%
# %matplotlib notebook
xticks=[0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75]
fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax1=plt.subplot(1,1,1)
data1.plot.bar(ax=ax1)
plt.show()

fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax1=plt.subplot(1,1,1)
data2.plot.bar(ax=ax1)
plt.show()

# fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
# ax1=plt.subplot(1,1,1)
# data3.plot.bar(ax=ax1)
# plt.show()

# fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
# ax1=plt.subplot(1,1,1)
# data4.plot.bar(ax=ax1)
# plt.show()

fig = plt.figure(figsize=(7,5)) #如果不传入参数默认画板1
ax5=plt.subplot(1,1,1)
data1.plot.bar(ax=ax1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="769.4545454545455">
# <img src="data:image/png;base64,..." width="769.4545454545455">
# <img src="data:image/png;base64,..." width="769.4545454545455">
